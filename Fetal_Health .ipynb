# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data= pd.read_csv('D:/projects/Fetal Health kaggle/fetal_health.csv', header=0)

# %%
data.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
data.shape
# Out:
# (2126, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.duplicated().sum()
# Out:
# 13

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (2113, 22)

# %%
data.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2113.000000    2113.000000     2113.000000           2113.000000
# mean       133.304780       0.003188        0.009517              0.004387
# std          9.837451       0.003871        0.046804              0.002941
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.005000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2113.000000           2113.000000               2113.000000
# mean              0.001901              0.000003                  0.000159
# ...

# %%
import seaborn as sns

# %%
sns.histplot(x= data['baseline value'])
# Out:
# <AxesSubplot:xlabel='baseline value', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data= data.corr(), annot= True,cmap= 'coolwarm')
plt.show()

# %%
data = data.drop(['histogram_mean','histogram_median','histogram_min'],axis=1)

# %%
#sns.pairplot(data=data,hue= 'fetal_health',corner= True)

# %%
v = data.drop('fetal_health',axis=1)
s = v.columns
df_col = list(s)

# %%
# for i in df_col:
#     fig,axes= plt.subplots()
#     sns.regplot(x= i, y='fetal_health',data=data)
#     plt.show()

# %%
# for i in df_col:
#     fig,axes= plt.subplots()
#     sns.swarmplot(x = 'fetal_health',y= i,data= data)
#     plt.show()

# %%
X = data.drop('fetal_health',axis=1)
Y= data['fetal_health']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
x_train,x_test,y_train,y_test  = train_test_split(X,Y, test_size= 0.3, random_state=0)
model_rf = RandomForestClassifier(n_estimators= 50)
model_rf.fit(x_train,y_train)
pred_rf = model_rf.predict(x_test)
accuracy_rf = metrics.accuracy_score(y_test,pred_rf)
print(accuracy_rf)
# Out:
# 0.944794952681388

# %%
RandomForestClassifier(bootstrap=True,criterion = 'gini')
imp_feature = pd.Series(model_rf.feature_importances_,index=df_col).sort_values(ascending=False)
imp_feature
# Out:
# percentage_of_time_with_abnormal_long_term_variability    0.146170
# abnormal_short_term_variability                           0.144203
# histogram_mode                                            0.113703
# mean_value_of_short_term_variability                      0.106448
# prolongued_decelerations                                  0.075107
# mean_value_of_long_term_variability                       0.054592
# uterine_contractions                                      0.051594
# baseline value                                            0.050908
# histogram_width                                           0.050612
# histogram_variance                                        0.042670
# accelerations                                             0.041937
# histogram_max                                             0.036888
# histogram_number_of_peaks                                 0.028918
# fetal_movement                                            0.021599
# ...

# %%
sns.barplot(x=imp_feature, y=imp_feature.index)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data1 = data.drop(['severe_decelerations','histogram_number_of_zeroes','histogram_tendency','light_decelerations'],axis=1)

# %%
X1= data1.drop('fetal_health',axis=1)
Y1 = data1['fetal_health']

# %%
x1_train,x1_test,y1_train,y1_test = train_test_split(X1,Y1,train_size=0.3,random_state=0)

# %%
model1_rf = RandomForestClassifier(n_estimators= 50)
model1_rf.fit(x1_train,y1_train)
pred1_rf = model1_rf.predict(x1_test)
accuracy1_rf = metrics.accuracy_score(y1_test,pred1_rf)
print(accuracy1_rf)
# Out:
# 0.9317567567567567

# %%
y1_test_arr= np.array(y1_test)

# %%
for i in range(20):
     print('The Actual value is {} and predicted value is {}'.format(y1_test_arr[i], pred1_rf[i]))
# Out:
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 2.0 and predicted value is 2.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 1.0 and predicted value is 1.0
# The Actual value is 2.0 and predicted value is 2.0
# ...

# %%
y1_test.nunique()
# Out:
# 3

# %%
cm = metrics.confusion_matrix(y1_test_arr,pred1_rf)
cm
# Out:
# array([[1140,    9,    3],
#        [  57,  144,    8],
#        [  15,    9,   95]], dtype=int64)
